# %% [markdown]
# <a href="https://colab.research.google.com/github/David8596/Labs/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторная работа 2. Управление ходом выполнения программы

# %% [markdown]
# Тер-Маркарян Давид ИНБ-б-о-26-2

# %% [markdown]
# ## Задание

# %% [markdown]
# Необходимо вычислить значение выражения:
# $$Z=\frac{1}{1\cdot3}-\frac{X}{2\cdot4}+\frac{X^2}{3\cdot5}-\frac{X^3}{4\cdot6}+...$$
# Для каждой переменной необходимо вывести ее значение и тип.

# %% [markdown]
# ## Анализ выражения и определение переменных

# %% [markdown]
# Проанализируем выражение и определим переменные, которые потребуются для выполнения задания. Независимые переменные: $X$. Переменная, которая должна быть вычислена на основе независимых: $Z$.
#
# Следует обратить внимание, что в выражении неизвестное число слагаемых, поэтому необходимо ввести переменную $N$ для представления количества слагаемых.
#
# Обратите внимание, что знаки слагаемых чередуются, а степени числителя и множетели знаменателя привязаны к порядковому номеру слагаемого.

# %% [markdown]
# ## Вычисление выражение, печать результатов

# %% [markdown]
# Код для вычисления значения выражения $Z$:

# %%
X = 2
N = 10
Z = 0
for i in range(1, N+1):
  chisl = X**(i-1)
  znam = i * (i+1)
  if i%2==1:
    Z += chisl / znam
  else:
    Z -= chisl/znam
print(Z)
# Out:
# -2.573593073593073

# %% [markdown]
# Решите пример в соответствии с индивидуальным заданием

# %%
X = 2
N = 10
Z = 0
for i in range(1, N+1):
  chisl = X**(i-1)
  znam = i * (i+1)
  if i%2==1:
    Z += chisl / znam
  else:
    Z -= chisl/znam
print(Z)
# Out:
# -2.573593073593073

# %% [markdown]
# ##Ответы на контрольные вопросы

# %% [markdown]
# 1.   Переменная – это имя, которое представляет место хранения в памяти
# компьютера
# 2.   Недопустимы: 99bottles - начинается с цифры; r&d - недопустимый символ
# 3.   Sales и sales это разные переменные, т.к. названия отличаются регистром первой буквы
# 4.   Недопустима, потому что 72 не может являться названием переменной, т.к. начинается с цифры и amount не текстовый тип данных. надо их поменять местами
# 5.   Терминал выведет "Значение равняетсяval"
# 6.    valuel = 99 - int
#       value2 = 45.9 - float
#       value3 = 7.0 - float
#       value4 = 7 - int
#       value5 = 'abc' -str
# 7.   Терминал выведет 0
# 8.
# ```
# for x in range(6):
#   print('Обожаю эту программу')
# ```
# 9.   0 1 2 3 4 5
# 10.  2 3 4 5
# 11.  0 100 200 300 400 500
# 12.  10 9 8 7 6
# 13.  Накопительная переменная - это переменная, которая создаётся выше определенного цикла for или while и используется в нём для накопления суммы, каждый раз обновляя число в новой итерации цикла
# 14.  Да, нужно, потому что если не проинициализировать переменную, то могут возникнуть ошибки или неверные значения. Ещё нужно, чтобы поставить точку отсчёта суммы
# 15.  Терминал выведет 15
# 16.  Терминал выведет 15 5
# 17.
#
# ```
# quantity += 1
# days_left -= 5
# price *= 10
# price /= 2
# ```
# 19.
#
# ```
# surname = input("Введите вашу фамилию: ")
# ```
# 20.  Бесконечный цикл - это цикл while, для которого всегда выполняется условие выполнения новой его итерации
# пример -
#
# ```
# while True:
#   print("бесконечный цикл whileЭ)
# ```
